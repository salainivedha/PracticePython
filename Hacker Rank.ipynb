966,61652552693,61652577814,67194618879,74383161477,85955959296,89652550751,93652477944,21108338968,34652543667,37652328151,55652233451,87652539850,32571097186,40723993012,55651520651,64694453230,90651546992,16424463257,30652454549,46652040625,50652464796,78652030601,79214782906,91362456247,12652118691,14281981322,25327978344,31163829289,69640622153,91652626527,89622348351,28640352692,47491929878,55712185746,75471480809,76652422707,23198072193,25496590385,59797420364,67652384677,73651397250,14650827571,27688422937,36389249828,36651897755,56649713637,62242378919,59652335156,74151638194,91571607735,15652292423,16196327945,18243980486,20652228450,36755726682,56652287806,56958367642,62509968090,80652161905,99379846319,99652284743,24516883569,58276857330,65794149530,69164832813,73174143770,74643720058,11651989097,35224736728,73267082597,80652234869,89773343664,93965583579,11988241202,24652173825,57447997883,63652184962,81651562579,13783916782,58368117141,71340255391,15761190637,17544075319,81651930255]
get_headers={"accept":"application/json, text/plain, */*",
             "cookie":"_gid=GA1.3.1698947721.1682141522; ak_bmsc=E4AB59B55EABEC3938E733C2EE2F3F8A~000000000000000000000000000000~...; _ga=GA1.3.824473361.1682141522; bm_sv=372E533D25C64AA02BB0EC8411FA9976~~1; _gat_gtag_UA_33406418_2=1; _gat_gtag_UA_54970022_1=1; _ga_P83LHMFZ97=GS1.1.1682141522.1.1.1682142184.0.0.0",
             "user-agent":"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36"}

get_headers1={"authority":"www.acnc.gov.au",
            "accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
             "cookie":"gid=GA1.3.1698947721.1682141522; ak_bmsc=E4AB59B55EABEC3938E733C2EE2F3F8A~000000000000000000000000000000~...; _ga=GA1.3.824473361.1682141522; _ga_P83LHMFZ97=GS1.1.1682141522.1.1.1682143128.0.0.0; bm_sv=372E533D25C64AA02BB0EC8411FA9976~~1",
             "user-agent":"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/112.0.0.0 Safari/537.36"}

file=open('nums.csv','w')

# %%
names=[]
for number in nums:
    url='https://www.acnc.gov.au/api/dynamics/search/charity?search={}'.format(number)
    res=requests.get(url,headers=get_headers)
    out=res.json()
    result=out['results']
    #print(number,url,res)
    for j in result:
        entity=j['uuid']
        url1="https://www.acnc.gov.au/api/dynamics/entity/{}".format(entity)
        res=requests.get(url1,headers=get_headers)
        print(entity,url1,res)
        res1=res.json()
        if res1['data'].get('ResponsiblePersons'):
            for i1 in res1['data']['ResponsiblePersons']:
                print(i1['Name'])
                names.append(i1['Name'])
                file.write(str(number)+','+i1['Name']+'\n')
# Out:
# 161259fc-927a-ed11-81ac-00224893bfad https://www.acnc.gov.au/api/dynamics/entity/161259fc-927a-ed11-81ac-00224893bfad <Response [200]>
# Machelle Cartner
# Jacob Vaughan
# Ross Cartner
# a3f8e851-f975-ed11-81ad-002248122b18 https://www.acnc.gov.au/api/dynamics/entity/a3f8e851-f975-ed11-81ad-002248122b18 <Response [200]>
# Justyna Hardy
# Vanessa Mills
# Lisa Sweet
# 68a93532-0576-ed11-81ad-00224893b0ed https://www.acnc.gov.au/api/dynamics/entity/68a93532-0576-ed11-81ad-00224893b0ed <Response [200]>
# Collin James
# Janet Batt
# Ruth Kerr
# Robert FRASER
# George Thomas
# Marilyn Walter
# Philip Kerr
# 332f66dd-3f70-ed11-81ad-00224893bfad https://www.acnc.gov.au/api/dynamics/entity/332f66dd-3f70-ed11-81ad-00224893bfad <Response [200]>
# Matthew Wilson
# Janet Hollingsworth
# Deidre Coombs
# 699b93da-e371-ed11-81ac-00224893bffb https://www.acnc.gov.au/api/dynamics/entity/699b93da-e371-ed11-81ac-00224893bffb <Response [200]>
# Jailson Barbosa De Souza
# Paul Chapman
# Jacques Payet
# ...

# %%
res.json()['results'][0]['uuid']
# Out:
# '6271b295-5d65-ed11-9562-00224893bfad'

# %%
res1['data']['ResponsiblePersons']
# Out:
# [{'Name': 'Brett Rowe',
#   'Role': 'Director',
#   'uuid': '3b75ad75-d65f-ed11-9562-00224893bfad'},
#  {'Name': 'Brett Rowe',
#   'Role': 'Public Officer',
#   'uuid': '3b75ad75-d65f-ed11-9562-00224893bfad'},
#  {'Name': 'Shannon Upston',
#   'Role': 'Director',
#   'uuid': 'a376ad75-d65f-ed11-9562-00224893bfad'},
#  {'Name': 'Colin Saunders',
#   'Role': 'Director',
#   'uuid': 'a22fec73-2b49-ed11-bba2-00224893bd7a'}]

# %%
out['results']
# Out:
# [{'type': 'charity',
#   'uuid': '3a379264-d366-ed11-9562-002248122b18',
#   'data': {'Name': 'ASK WELLBEING SERVICES LIMITED',
#    'Abn': '30663864668',
#    'Status': 'Registered',
#    'CharitySize': None,
#    'AddressSuburb': 'Penrith',
#    'AddressStateOrProvince': 'NSW',
#    'ChildMemberStartDate': None,
#    'ChildMemberEndDate': None}}]

# %%
names=[]
file=open('num_total.csv','r')
for i in file:
    names.append(i.split(',')[1])

# %%
from collections import Counter, OrderedDict
values=Counter(names)
values.most_common()
# Out:
# [('Michael Lennon\n', 5),
#  ('Brian Motz\n', 4),
#  ('Kris Daff\n', 4),
#  ('Thomas Billings\n', 4),
#  ('Philip Gentry\n', 3),
#  ('Barry Schipplock\n', 3),
#  ('Melissa Hall\n', 3),
#  ('Kathleen Jones\n', 3),
#  ('Leo Wursthorn\n', 3),
#  ('Penelope Williams\n', 3),
#  ('Jailson Barbosa De Souza\n', 2),
#  ('Paul Chapman\n', 2),
#  ('Jacques Payet\n', 2),
#  ('Nathanael Tyler\n', 2),
#  ('Benjamin Thiel\n', 2),
#  ('Miguel Gutierrez\n', 2),
#  ('John Kent\n', 2),
#  ('Gilbert Wallbank\n', 2),
#  ('Gary Suter\n', 2),
#  ('Mark Oldham\n', 2),
#  ('Michael Rushworth\n', 2),
#  ('Peter Sobey\n', 2),
#  ('Malcolm Wilson\n', 2),
#  ('Brett Rowe\n', 2),
#  ('Bruce Turner\n', 2),
#  ('Bonita Bloomfield\n', 2),
#  ('Tracey Bloomfield\n', 2),
#  ('Christina Bosly-Pask\n', 2),
#  ('Stefan Romaniw\n', 2),
#  ('Kateryna Argyrou\n', 2),
#  ('Jarema Polatajko\n', 2),
#  ('Robert Henderson\n', 2),
#  ('Stephen Millard\n', 2),
#  ('Peter Holdsworth\n', 2),
#  ('Celine Bowler\n', 2),
# ...
